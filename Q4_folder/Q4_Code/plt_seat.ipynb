# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
from scipy import stats

# %%
# Read csv file
plt_seat_df = Path("../Input/seat_data.csv")
df = pd.read_csv(plt_seat_df)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 brand  year  price_in_euro  power_ps
# 0         59209      181533  seat  2019          16990        95
# 1         59210      181535  seat  2019          12100        60
# 2         59211      181536  seat  2019          19999       116
# 3         59212      181537  seat  2019          14380       116
# 4         59213      181538  seat  2019          13990       116

# %%
#Setting up a, b for correlation coefficient test
a, b = np.polyfit(df['power_ps'], df['price_in_euro'], 1)

# %%
#Plotting Graph (Scatter, x&y labels, title, best fit line)
plt.scatter(df['power_ps'], df['price_in_euro'], marker="o", facecolors="purple", edgecolors="black",
            alpha=0.5)
plt.xlabel("power(ps)")
plt.ylabel("price(euro)")
plt.title("Seat Power and Price Relations")
plt.plot(df['power_ps'], a*df['power_ps']+b)
plt.savefig('../Output/Seat_Graph.png')

# %%
# Pearson's Correlation Test
df['price_in_euro'].corr(df['power_ps'])
# Out:
# 0.5146972013415813
