# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
from scipy import stats

# %%
# Read csv
plt_volks_df = Path("../../Input/Caddy_vk_data.csv")
df = pd.read_csv(plt_volks_df)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       brand   model  year  price_in_euro  power_ps
# 0         78750      237945  volkswagen   Caddy  2019          31500       150
# 1         78756      237951  volkswagen   Caddy  2019          25480       102
# 2         78757      237952  volkswagen   Caddy  2019          29890       150
# 3         78760      237955  volkswagen   Caddy  2019          24480       102
# 4         78775      237973  volkswagen   Caddy  2019          23849       102

# %%
#Setting up a, b for correlation coefficient test
a, b = np.polyfit(df['power_ps'], df['price_in_euro'], 1)

# %%
#Plotting Graph (Scatter, x&y labels, title, best fit line)
plt.scatter(df['power_ps'], df['price_in_euro'], marker="o", facecolors="red", edgecolors="black",
            alpha=0.5)
plt.xlabel("power(ps)")
plt.ylabel("price(euro)")
plt.title("Caddy Power and Price Relations")
plt.plot(df['power_ps'], a*df['power_ps']+b)
plt.savefig('../../Output/Caddy_Graph.png')

# %%
# Pearson's Correlation Test
df['price_in_euro'].corr(df['power_ps'])
# Out:
# 0.16109220979478286
