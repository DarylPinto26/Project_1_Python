# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
from scipy import stats

# %%
# Read csv
plt_volks_df = Path("../../Input/T-Cross_vk_data.csv")
df = pd.read_csv(plt_volks_df)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       brand     model  year  price_in_euro  \
# 0         78771      237968  volkswagen   T-Cross  2019          23930
# 1         78798      237997  volkswagen   T-Cross  2019          18300
# 2         78843      238047  volkswagen   T-Cross  2019          23180
# 3         78861      238066  volkswagen   T-Cross  2019          21489
# 4         78893      238101  volkswagen   T-Cross  2019          20690
#
#    power_ps
# 0       116
# 1        95
# 2       116
# 3       116
# 4       116

# %%
#Setting up a, b for correlation coefficient test
a, b = np.polyfit(df['power_ps'], df['price_in_euro'], 1)

# %%
#Plotting Graph (Scatter, x&y labels, title, best fit line)
plt.scatter(df['power_ps'], df['price_in_euro'], marker="o", facecolors="red", edgecolors="black",
            alpha=0.5)
plt.xlabel("power(ps)")
plt.ylabel("price(euro)")
plt.title("T-Cross Power and Price Relations")
plt.plot(df['power_ps'], a*df['power_ps']+b)
plt.savefig('../../Output/T-Cross_Graph.png')

# %%
# Pearson's Correlation Test
df['price_in_euro'].corr(df['power_ps'])
# Out:
# 0.3444249390156872
