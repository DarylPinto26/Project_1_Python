# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
from scipy import stats

# %%
# Read csv
plt_volks_df = Path("../../Input/T-Roc_vk_data.csv")
df = pd.read_csv(plt_volks_df)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       brand   model  year  price_in_euro  power_ps
# 0         78827      238031  volkswagen   T-Roc  2019          24430       150
# 1         78828      238032  volkswagen   T-Roc  2019          24970       150
# 2         78847      238051  volkswagen   T-Roc  2019          24630       150
# 3         78868      238074  volkswagen   T-Roc  2019          56150       150
# 4         78873      238079  volkswagen   T-Roc  2019          23950       190

# %%
#Setting up a, b for correlation coefficient test
a, b = np.polyfit(df['power_ps'], df['price_in_euro'], 1)

# %%
#Plotting Graph (Scatter, x&y labels, title, best fit line)
plt.scatter(df['power_ps'], df['price_in_euro'], marker="o", facecolors="red", edgecolors="black",
            alpha=0.5)
plt.xlabel("power(ps)")
plt.ylabel("price(euro)")
plt.title("T-Roc Power and Price Relations")
plt.plot(df['power_ps'], a*df['power_ps']+b)
plt.savefig('../../Output/T-Roc_Graph.png')

# %%
# Pearson's Correlation Test
df['price_in_euro'].corr(df['power_ps'])
# Out:
# 0.4037062687800289
