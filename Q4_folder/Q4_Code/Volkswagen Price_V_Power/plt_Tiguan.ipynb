# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
from scipy import stats

# %%
# Read csv
plt_volks_df = Path("../../Input/Tiguan_vk_data.csv")
df = pd.read_csv(plt_volks_df)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       brand    model  year  price_in_euro  \
# 0         78745      237939  volkswagen   Tiguan  2019          26930
# 1         78748      237942  volkswagen   Tiguan  2019          23220
# 2         78761      237957  volkswagen   Tiguan  2019          23939
# 3         78763      237959  volkswagen   Tiguan  2019          29930
# 4         78765      237962  volkswagen   Tiguan  2019          34990
#
#    power_ps
# 0       150
# 1       150
# 2       150
# 3       150
# 4       190

# %%
#Setting up a, b for correlation coefficient test
a, b = np.polyfit(df['power_ps'], df['price_in_euro'], 1)

# %%
#Plotting Graph (Scatter, x&y labels, title, best fit line)
plt.scatter(df['power_ps'], df['price_in_euro'], marker="o", facecolors="red", edgecolors="black",
            alpha=0.5)
plt.xlabel("power(ps)")
plt.ylabel("price(euro)")
plt.title("Tiguan Power and Price Relations")
plt.plot(df['power_ps'], a*df['power_ps']+b)
plt.savefig('../../Output/Tiguan_Graph.png')

# %%
# Pearson's Correlation Test
df['price_in_euro'].corr(df['power_ps'])
# Out:
# 0.6146277903244333
