# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
from scipy import stats

# %%
# Read csv
plt_volks_df = Path("../../Input/Golf_vk_data.csv")
df = pd.read_csv(plt_volks_df)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       brand  model  year  price_in_euro  power_ps
# 0         78747      237941  volkswagen   Golf  2019          19890       131
# 1         78821      238022  volkswagen   Golf  2019          34750       300
# 2         78835      238039  volkswagen   Golf  2019          18350       116
# 3         78836      238040  volkswagen   Golf  2019          18550       116
# 4         78851      238055  volkswagen   Golf  2019          21440       131

# %%
#Setting up a, b for correlation coefficient test
a, b = np.polyfit(df['power_ps'], df['price_in_euro'], 1)

# %%
#Plotting Graph (Scatter, x&y labels, title, best fit line)
plt.scatter(df['power_ps'], df['price_in_euro'], marker="o", facecolors="red", edgecolors="black",
            alpha=0.5)
plt.xlabel("power(ps)")
plt.ylabel("price(euro)")
plt.title("Golf Power and Price Relations")
plt.plot(df['power_ps'], a*df['power_ps']+b)
plt.savefig('../../Output/Golf_Graph.png')

# %%
# Pearson's Correlation Test
df['price_in_euro'].corr(df['power_ps'])
# Out:
# 0.5709794653888498
