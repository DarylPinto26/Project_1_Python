# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
from scipy import stats

# %%
# Read csv file
plt_volks_df = Path("../Input/volkswagen_data.csv")
df = pd.read_csv(plt_volks_df)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       brand  year  price_in_euro  power_ps
# 0         78745      237939  volkswagen  2019          26930       150
# 1         78746      237940  volkswagen  2019          28220       116
# 2         78747      237941  volkswagen  2019          19890       131
# 3         78748      237942  volkswagen  2019          23220       150
# 4         78749      237944  volkswagen  2019          44545       150

# %%
#Setting up a, b for correlation coefficient test
a, b = np.polyfit(df['power_ps'], df['price_in_euro'], 1)

# %%
#Plotting Graph (Scatter, x&y labels, title, best fit line)
plt.scatter(df['power_ps'], df['price_in_euro'], marker="o", facecolors="red", edgecolors="black",
            alpha=0.5)
plt.xlabel("power(ps)")
plt.ylabel("price(euro)")
plt.title("Volkswagen Power and Price Relations")
plt.plot(df['power_ps'], a*df['power_ps']+b)
plt.savefig('../Output/Volkswagen_Graph.png')

# %%
# Pearson's Correlation Test
df['price_in_euro'].corr(df['power_ps'])
# Out:
# 0.45311782114879673
